# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitasankhwar/pwdatascience/blob/master/Statistics_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment Code: DS-AG-005
# ## Statistics Basics | Assignment
#
# ---
#
# ## Question 1: What is the difference between descriptive statistics and inferential statistics? Explain with examples.
#
# **Answer:**
#
# Descriptive statistics are used to summarize and describe the main characteristics of a dataset. It helps in organizing and presenting data in a meaningful way using measures such as mean, median, mode, variance, and standard deviation. Graphical methods such as histograms, bar charts, and boxplots are also part of descriptive statistics. For example, calculating the average marks of students in a class is an example of descriptive statistics.
#
# Inferential statistics, on the other hand, involves making predictions or conclusions about a larger population based on a sample of data. It uses techniques such as hypothesis testing, confidence intervals, and regression analysis. For example, predicting the voting preference of an entire population based on a survey sample is an example of inferential statistics.
#
# ---
#
# ## Question 2: What is sampling in statistics? Explain the differences between random and stratified sampling.
#
# **Answer:**
#
# Sampling is the process of selecting a subset of individuals or observations from a larger population in order to analyze and draw conclusions about the entire population.
#
# Random sampling is a method where every individual in the population has an equal chance of being selected. This helps reduce bias and ensures that the sample represents the population fairly.
#
# Stratified sampling divides the population into smaller groups called strata based on certain characteristics such as age, income, or gender. Samples are then randomly selected from each group. This method ensures that all important subgroups of the population are represented in the sample.
#
# ---
#
# ## Question 3: Define mean, median, and mode. Explain why these measures of central tendency are important.
#
# **Answer:**
#
# Mean is the average value of a dataset and is calculated by dividing the sum of all observations by the number of observations.
#
# Median is the middle value of a dataset when the values are arranged in ascending or descending order.
#
# Mode is the value that appears most frequently in a dataset.
#
# These measures are important because they help summarize large datasets with a single representative value. They provide insights into the typical value of the data and help in understanding data distribution and trends.
#
# ---
#
# ## Question 4: Explain skewness and kurtosis. What does a positive skew imply about the data?
#
# **Answer:**
#
# Skewness measures the asymmetry of the probability distribution of a dataset. If the data distribution is symmetric, skewness is zero. If the distribution is skewed to one side, skewness becomes positive or negative.
#
# Kurtosis measures the shape of the distribution and indicates whether the data has heavy tails or light tails compared to a normal distribution.
#
# A positive skew (right skew) means that the tail of the distribution extends toward the right side. This indicates that most of the data values are concentrated on the left side with a few extremely large values on the right.

# %%
# Question 5:
# Compute the mean, median, and mode of the given list of numbers

import statistics

numbers = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]

mean_value = statistics.mean(numbers)
median_value = statistics.median(numbers)
mode_value = statistics.mode(numbers)

print("Mean:", mean_value)
print("Median:", median_value)
print("Mode:", mode_value)
# Out:
# Mean: 19.6
# Median: 19
# Mode: 12

# %%
# Question 6:
# Compute covariance and correlation coefficient between two datasets

import numpy as np

list_x = [10, 20, 30, 40, 50]
list_y = [15, 25, 35, 45, 60]

covariance = np.cov(list_x, list_y)[0][1]
correlation = np.corrcoef(list_x, list_y)[0][1]

print("Covariance:", covariance)
print("Correlation Coefficient:", correlation)
# Out:
# Covariance: 275.0
# Correlation Coefficient: 0.995893206467704

# %%
# Question 7:
# Draw a boxplot for the given data and identify outliers

import matplotlib.pyplot as plt

data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]

plt.boxplot(data)
plt.title("Boxplot of Data")
plt.show()

# Outlier explanation:
print("Potential outlier: 35 appears far from the rest of the data.")
# Out:
# Potential outlier: 35 appears far from the rest of the data.

# %%
# Question 8:
# Compute correlation between advertising spend and daily sales

import numpy as np

advertising_spend = [200, 250, 300, 400, 500]
daily_sales = [2200, 2450, 2750, 3200, 4000]

correlation = np.corrcoef(advertising_spend, daily_sales)[0][1]

print("Correlation between Advertising Spend and Sales:", correlation)
# Out:
# Correlation between Advertising Spend and Sales: 0.9935824101653329

# %% [markdown]
# ### Explanation
#
# Covariance measures how two variables change together. A positive covariance indicates that both variables tend to increase together, while a negative covariance indicates an inverse relationship.
#
# Correlation standardizes covariance and measures the strength and direction of the relationship between two variables. Its value ranges between -1 and 1. A value close to 1 indicates a strong positive relationship, meaning that as advertising spend increases, daily sales also increase.

# %%
# Question 9:
# Create a histogram for survey scores using Matplotlib

import matplotlib.pyplot as plt

survey_scores = [7, 8, 5, 9, 6, 7, 8, 9, 10, 4, 7, 6, 9, 8, 7]

plt.hist(survey_scores, bins=6)
plt.xlabel("Survey Scores")
plt.ylabel("Frequency")
plt.title("Customer Satisfaction Survey Distribution")
plt.show()

# %% [markdown]
# ### Explanation
#
# To understand the distribution of customer satisfaction scores, we use summary statistics such as mean, median, and standard deviation to describe the central tendency and spread of the data.
#
# A histogram helps visualize how frequently each score appears and whether the distribution is symmetric, skewed, or concentrated around certain values. This helps the company understand overall customer satisfaction before launching a new product.
